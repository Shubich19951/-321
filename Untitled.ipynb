# %%
import pandas as pd
import requests
import numpy as np
from matplotlib import pyplot as plt

import logging
from pymongo import MongoClient
import pymongo
from datetime import datetime

# %%
import seaborn as sn
sn.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (20,10)
pd.set_option('display.max_columns', 2000)
plt.rcParams.update({'font.size': 12})

# %%
df = pd.read_csv('145_01-01-2019_31-12-2019.csv', sep=',')

# %%
df.index = pd.to_datetime(df['day'].values, format="%d-%m-%Y")
df = df.drop(['day'],axis=1)

# %%
len(df)
# Out:
# 365

# %%
hist_data = np.histogram(df['rate'], 20)

# %%
hist_data = np.histogram(df['rate'], 12)
plt.hist(df['rate'].values, 12)
plt.plot(hist_data[1][1:], hist_data[0], linewidth=5)
plt.show()

# %%
plt.plot(df.index[::5].values, [df['rate'][i:i+5].std() for i in range(0, len(df),5)])

# %%
import statsmodels.tsa.api as sm

# %%
sm.seasonal_decompose(df['rate']).plot()

# %%
df_m = df.resample('10D').mean()

# %%
plt.plot((df_m['rate']-df_m['rate'].shift(1))[1:])

# %%
plt.plot(df.index.values, df['rate'].values)

# %%
df.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=365, freq=None)

# %%
sm.seasonal_decompose(x=df['rate'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-03fcbae7acf5> in <module>
# ----> 1 sm.seasonal_decompose(x=df['rate'])
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided, extrapolate_trend)
#     125             freq = pfreq
#     126         else:
# --> 127             raise ValueError("You must specify a freq or x must be a "
#     128                              "pandas object with a timeseries index with "
#     129                              "a freq not set to None")
#
# ValueError: You must specify a freq or x must be a pandas object with a timeseries index with a freq not set to None
